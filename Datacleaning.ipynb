# %%
#import libraries
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Create a file path to the volcanic_data.csv base file.
csv_path = Path("volcanic_database.csv")

# Import the volcanic_database.csv file as a DataFrame
volcanic_df = pd.read_csv(csv_path, encoding="utf-8")
# Check the special characters imported correctly
volcanic_df.head(7)
# Out:
#    Year  Month   Day Flag Tsunami Flag Earthquake Volcano Name  \
# 0  1280    NaN   NaN          NaN             NaN     Quilotoa
# 1  1540    NaN   NaN      Tsunami             NaN    Augustine
# 2  1660    NaN   NaN      Tsunami             NaN  Long Island
# 3  1858    4.0  23.0          NaN      Earthquake    Tate-yama
# 4  1864    1.0   3.0          NaN             NaN        Kelut
# 5  1873    1.0  16.0          NaN             NaN       Ragang
# 6  1902    8.0   7.0          NaN             NaN   Tori-shima
#
#                Location           Country  Elevation     Volcano Type  ...  \
# 0               Ecuador           Ecuador       3914          Caldera  ...
# 1             Alaska-SW     United States       1252        Lava dome  ...
# 2      New Guinea-NE of  Papua New Guinea       1280  Complex volcano  ...
# 3          Honshu-Japan             Japan       2621    Stratovolcano  ...
# 4                  Java         Indonesia       1731    Stratovolcano  ...
# ...

# %%
# List all the columns in the table
volcanic_df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Flag Tsunami', 'Flag Earthquake',
#        'Volcano Name', 'Location', 'Country', 'Elevation', 'Volcano Type',
#        'Status', 'Volcanic Explosivity Index', 'Volcano : Deaths',
#        'Volcano : Deaths Description', 'Volcano : Injuries',
#        'Volcano : Injuries Description', 'Volcano : Damage (in M$)',
#        'Volcano : Damage Description', 'Volcano : Houses destroyed',
#        'Volcano : Houses destroyed Description', 'Total Effects : Deaths',
#        'Total Effects : Deaths Description', 'Total Effects : Missing',
#        'Total Effects : Missing Description', 'Total Effects : Injuries',
#        'Total Effects : Injuries Description',
#        'Total Effects : Damages in million Dollars',
#        'Total Effects : Damage Description',
#        'Total Effects : Houses Destroyed',
#        'Total Effects : Houses Destroyed Description', 'Coordinates',
#        'Earthquakes : Houses damaged Description',
# ...

# %%
# Identify incomplete rows
volcanic_df.count()
# Out:
# Year                                            810
# Month                                           708
# Day                                             647
# Flag Tsunami                                    143
# Flag Earthquake                                  65
# Volcano Name                                    810
# Location                                        810
# Country                                         810
# Elevation                                       810
# Volcano Type                                    810
# Status                                          810
# Volcanic Explosivity Index                      637
# Volcano : Deaths                                429
# Volcano : Deaths Description                    552
# Volcano : Injuries                               94
# Volcano : Injuries Description                  118
# Volcano : Damage (in M$)                         18
# Volcano : Damage Description                    221
# ...

# %%
# Delete columns we don't want
volcanic_df.drop(['Location', 'Volcano : Deaths Description', 'Volcano : Injuries', 'Volcano : Injuries Description', 
                  'Volcano : Damage (in M$)', 'Volcano : Damage Description', 'Volcano : Houses destroyed', 'Volcano : Houses destroyed Description', 'Total Effects : Deaths Description', 'Total Effects : Missing', 'Total Effects : Missing Description', 'Total Effects : Injuries', 'Total Effects : Injuries Description', 'Total Effects : Damages in million Dollars', 'Total Effects : Damage Description', 'Total Effects : Houses Destroyed', 'Total Effects : Houses Destroyed Description', 'Earthquakes : Houses damaged Description', 'Total Effects : Houses Damaged Description', 'Total Effects : Missing', 'Total Effects : Missing Description'], axis=1, inplace=True)
volcanic_df.head()
# Out:
#    Year  Month   Day Flag Tsunami Flag Earthquake Volcano Name  \
# 0  1280    NaN   NaN          NaN             NaN     Quilotoa
# 1  1540    NaN   NaN      Tsunami             NaN    Augustine
# 2  1660    NaN   NaN      Tsunami             NaN  Long Island
# 3  1858    4.0  23.0          NaN      Earthquake    Tate-yama
# 4  1864    1.0   3.0          NaN             NaN        Kelut
#
#             Country  Elevation     Volcano Type       Status  \
# 0           Ecuador       3914          Caldera  Radiocarbon
# 1     United States       1252        Lava dome   Historical
# 2  Papua New Guinea       1280  Complex volcano   Historical
# 3             Japan       2621    Stratovolcano   Historical
# 4         Indonesia       1731    Stratovolcano   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Effects : Deaths  \
# 0                         6.0               NaN                     NaN
# ...

# %%
# check the data in the last columns 
volcanic_df.count()
# Out:
# Year                          810
# Month                         708
# Day                           647
# Flag Tsunami                  143
# Flag Earthquake                65
# Volcano Name                  810
# Country                       810
# Elevation                     810
# Volcano Type                  810
# Status                        810
# Volcanic Explosivity Index    637
# Volcano : Deaths              429
# Total Effects : Deaths        448
# Coordinates                   810
# dtype: int64

# %%
#data_type
volcanic_df.dtypes
# Out:
# Year                            int64
# Month                         float64
# Day                           float64
# Flag Tsunami                   object
# Flag Earthquake                object
# Volcano Name                   object
# Country                        object
# Elevation                       int64
# Volcano Type                   object
# Status                         object
# Volcanic Explosivity Index    float64
# Volcano : Deaths              float64
# Total Effects : Deaths        float64
# Coordinates                    object
# dtype: object

# %%
# Rename the 'Total Effects : Deaths' to 'Total Deaths'
new_volcanic_df = volcanic_df.rename(columns={'Total Effects : Deaths': 'Total Deaths'})
print(new_volcanic_df)
# Out:
#      Year  Month   Day Flag Tsunami Flag Earthquake     Volcano Name  \
# 0    1280    NaN   NaN          NaN             NaN         Quilotoa
# 1    1540    NaN   NaN      Tsunami             NaN        Augustine
# 2    1660    NaN   NaN      Tsunami             NaN      Long Island
# 3    1858    4.0  23.0          NaN      Earthquake        Tate-yama
# 4    1864    1.0   3.0          NaN             NaN            Kelut
# ..    ...    ...   ...          ...             ...              ...
# 805  2006    5.0  20.0      Tsunami             NaN  Soufriere Hills
# 806  2015    4.0  22.0          NaN             NaN          Calbuco
# 807  2017    9.0  12.0          NaN             NaN    Campi Flegrei
# 808  2018    1.0   5.0          NaN             NaN          Kadovar
# 809  2018    3.0  21.0          NaN             NaN             Ijen
#
#               Country  Elevation     Volcano Type       Status  \
# 0             Ecuador       3914          Caldera  Radiocarbon
# ...

# %%
# Replace NaN with '0' in the 'Day' column and convert to integer
new_volcanic_df['Day'] = new_volcanic_df['Day'].fillna('0').astype(float).astype(int)
new_volcanic_df.head()
# Out:
#    Year  Month  Day Flag Tsunami Flag Earthquake Volcano Name  \
# 0  1280    NaN    0          NaN             NaN     Quilotoa
# 1  1540    NaN    0      Tsunami             NaN    Augustine
# 2  1660    NaN    0      Tsunami             NaN  Long Island
# 3  1858    4.0   23          NaN      Earthquake    Tate-yama
# 4  1864    1.0    3          NaN             NaN        Kelut
#
#             Country  Elevation     Volcano Type       Status  \
# 0           Ecuador       3914          Caldera  Radiocarbon
# 1     United States       1252        Lava dome   Historical
# 2  Papua New Guinea       1280  Complex volcano   Historical
# 3             Japan       2621    Stratovolcano   Historical
# 4         Indonesia       1731    Stratovolcano   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Deaths     Coordinates
# 0                         6.0               NaN           NaN    -0.85, -78.9
# ...

# %%
# Replace NaN with '0' in the 'Month' column and convert to integer
new_volcanic_df['Month'] = new_volcanic_df['Month'].fillna('0').astype(float).astype(int)
new_volcanic_df.head()
# Out:
#    Year  Month  Day Flag Tsunami Flag Earthquake Volcano Name  \
# 0  1280      0    0          NaN             NaN     Quilotoa
# 1  1540      0    0      Tsunami             NaN    Augustine
# 2  1660      0    0      Tsunami             NaN  Long Island
# 3  1858      4   23          NaN      Earthquake    Tate-yama
# 4  1864      1    3          NaN             NaN        Kelut
#
#             Country  Elevation     Volcano Type       Status  \
# 0           Ecuador       3914          Caldera  Radiocarbon
# 1     United States       1252        Lava dome   Historical
# 2  Papua New Guinea       1280  Complex volcano   Historical
# 3             Japan       2621    Stratovolcano   Historical
# 4         Indonesia       1731    Stratovolcano   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Deaths     Coordinates
# 0                         6.0               NaN           NaN    -0.85, -78.9
# ...

# %%
# Sort the DataFrame by the 'Year' column
df_volanic = new_volcanic_df.sort_values('Year')
# Reset the index based on the sorted order
df_volanic= df_volanic.reset_index(drop=True)
df_volanic.head()
# Out:
#    Year  Month  Day Flag Tsunami Flag Earthquake    Volcano Name  \
# 0 -1010      0    0          NaN             NaN      Tungurahua
# 1    46      0    0      Tsunami             NaN       Santorini
# 2    50      0    0          NaN             NaN          Ambrym
# 3    60      0    0          NaN             NaN  Bona-Churchill
# 4    79      8   25      Tsunami      Earthquake        Vesuvius
#
#          Country  Elevation        Volcano Type       Status  \
# 0        Ecuador       5023       Stratovolcano   Historical
# 1         Greece        329      Shield volcano   Historical
# 2        Vanuatu       1334  Pyroclastic shield   Historical
# 3  United States       5005       Stratovolcano  Radiocarbon
# 4          Italy       1281     Complex volcano   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Deaths      Coordinates
# 0                         5.0               NaN           NaN  -1.467, -78.442
# ...

# %%
# Delete rows where 'Year' is -1010
df_clean= df_volanic.drop(0)
# Reset the index
df_clean.head()
# Out:
#    Year  Month  Day Flag Tsunami Flag Earthquake     Volcano Name  \
# 1    46      0    0      Tsunami             NaN        Santorini
# 2    50      0    0          NaN             NaN           Ambrym
# 3    60      0    0          NaN             NaN   Bona-Churchill
# 4    79      8   25      Tsunami      Earthquake         Vesuvius
# 5   200      0    0          NaN             NaN  Arhab, Harra of
#
#          Country  Elevation        Volcano Type       Status  \
# 1         Greece        329      Shield volcano   Historical
# 2        Vanuatu       1334  Pyroclastic shield   Historical
# 3  United States       5005       Stratovolcano  Radiocarbon
# 4          Italy       1281     Complex volcano   Historical
# 5          Yemen       3100      Volcanic field   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Deaths     Coordinates
# 1                         3.0               NaN           NaN  36.404, 25.396
# ...

# %%
# Reset the index to create a new index
df = df_clean.reset_index(drop=True)
df.head()
# Out:
#    Year  Month  Day Flag Tsunami Flag Earthquake     Volcano Name  \
# 0    46      0    0      Tsunami             NaN        Santorini
# 1    50      0    0          NaN             NaN           Ambrym
# 2    60      0    0          NaN             NaN   Bona-Churchill
# 3    79      8   25      Tsunami      Earthquake         Vesuvius
# 4   200      0    0          NaN             NaN  Arhab, Harra of
#
#          Country  Elevation        Volcano Type       Status  \
# 0         Greece        329      Shield volcano   Historical
# 1        Vanuatu       1334  Pyroclastic shield   Historical
# 2  United States       5005       Stratovolcano  Radiocarbon
# 3          Italy       1281     Complex volcano   Historical
# 4          Yemen       3100      Volcanic field   Historical
#
#    Volcanic Explosivity Index  Volcano : Deaths  Total Deaths     Coordinates
# 0                         3.0               NaN           NaN  36.404, 25.396
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv('output_volcanic.csv', index=False)
